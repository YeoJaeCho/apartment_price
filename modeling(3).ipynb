# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np
from sklearn.model_selection import train_test_split

# %%
apt = pd.read_csv('./apartment_price.csv')
apt.head()
# Out:
#          apt_name  use_area  transaction_year_month  transaction_date   price  \
# 0  개포6차우성아파트1동~8동     79.97                  202112                 4  215000
# 1  개포6차우성아파트1동~8동     79.97                  202204                12  220000
# 2  개포6차우성아파트1동~8동     79.97                  202204                21  220000
# 3  개포6차우성아파트1동~8동     79.97                  202205                27  216000
# 4       개포래미안포레스트     74.66                  202109                16  253000
#
#    floor  year_of_completion   gu dong  nursing_room_num  ...  teacher_num  \
# 0      3              1987.0  강남구  개포동              4.78  ...        12.43
# 1      4              1987.0  강남구  개포동              4.78  ...        12.43
# 2      2              1987.0  강남구  개포동              4.78  ...        12.43
# 3      2              1987.0  강남구  개포동              4.78  ...        12.43
# 4      2              2020.0  강남구  개포동              4.78  ...        12.43
#
#    permission_year  commuting_vehicle_sum  day_care_num  park_area  \
# 0           2007.0                     20           180    7768.75
# 1           2007.0                     20           180    7768.75
# 2           2007.0                     20           180    7768.75
# 3           2007.0                     20           180    7768.75
# 4           2007.0                     20           180    7768.75
#
#    one_park_area  citypark_area  one_citypark_area  walkpark_area  \
# 0          14.28        6479.09              11.91        3628.21
# 1          14.28        6479.09              11.91        3628.21
# 2          14.28        6479.09              11.91        3628.21
# 3          14.28        6479.09              11.91        3628.21
# 4          14.28        6479.09              11.91        3628.21
#
#    one_walkpark_area
# 0               6.67
# 1               6.67
# 2               6.67
# 3               6.67
# 4               6.67
#
# [5 rows x 24 columns]

# %%
train, test = train_test_split(apt, test_size=0.2, random_state = 7916, stratify = apt['gu'])

# %%
target = test['price'].copy()
test = test.drop('price', axis = 1)

# %%
all_data = pd.concat([train, test], axis = 0, ignore_index = True)  # 행축으로 연결
all_data.tail()
# Out:
#                 apt_name  use_area  transaction_year_month  transaction_date  \
# 321698                우방    114.79                  202003                27
# 321699               한마을    149.97                  201803                24
# 321700  정릉우성아파트 101~105동     84.99                  202002                22
# 321701            양평현대6차     59.98                  201806                21
# 321702       은평뉴타운마고정2단지     84.04                  201806                23
#
#         price  floor  year_of_completion    gu   dong  nursing_room_num  ...  \
# 321698    NaN      2              1999.0   관악구    신림동              4.63  ...
# 321699    NaN     24              1999.0   구로구    개봉동              4.29  ...
# 321700    NaN      8              2000.0   성북구    정릉동              4.32  ...
# 321701    NaN      5              2000.0  영등포구  양평동3가              4.63  ...
# 321702    NaN      2              2009.0   은평구    진관동              5.32  ...
#
#         teacher_num  permission_year  commuting_vehicle_sum  day_care_num  \
# 321698         9.83           2005.0                     32           185
# 321699         9.13           2007.0                     28           261
# 321700         9.76           2007.0                     32           207
# 321701        12.32           2009.0                     17           221
# 321702        11.59           2010.0                     59           207
#
#         park_area  one_park_area  citypark_area  one_citypark_area  \
# 321698   12431.42          24.38       12424.91              24.37
# 321699    3641.45           8.42        3319.70               7.68
# 321700    8507.35          19.03        4586.77              10.26
# 321701    3009.28           7.39         664.47               1.63
# 321702   14365.72          29.68        6597.53              13.63
#
#         walkpark_area  one_walkpark_area
# 321698        1910.24               3.75
# 321699        1533.35               3.55
# 321700        1640.43               3.67
# 321701        2957.42               7.26
# 321702        2200.62               4.55
#
# [5 rows x 24 columns]

# %%
drop_features = ['apt_name', 'gu', 'dong', 'transaction_year_month', 'transaction_date', 'year_of_completion', 'commuting_vehicle_sum', 
                 'day_care_num', 'permission_year', 'park_area', 'one_park_area', 'citypark_area', 'one_citypark_area']
all_data = all_data.drop(drop_features, axis = 1)

# %%
X_train = all_data[~pd.isnull(all_data['price'])]
X_test = all_data[pd.isnull(all_data['price'])]

# %%
y_train = X_train['price']
X_train = X_train.drop(['price'], axis = 1)

X_test = X_test.drop(['price'], axis = 1)

# %% [markdown]
# ## (11) Bagging (Ensemble)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.ensemble import BaggingRegressor

# %%
rnd_forest = RandomForestRegressor(max_depth=20, max_features=10, n_estimators=220, random_state=7916)

# %%
bag_reg = BaggingRegressor(rnd_forest, n_jobs=-1, random_state=7916)

# %%
scores = cross_val_score(bag_reg, X_train, log_y, scoring = 'neg_mean_squared_error', cv = 3)
-scores.mean()
# Out:
# 0.0751410186533898

# %% [markdown]
# - Bagging 모델 mse = 0.0751410186533898
